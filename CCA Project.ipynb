# %% [markdown]
# # CCA Project

# %% [markdown]
# ### Load Data and Libraries

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
# %matplotlib inline 

import xlrd

from apyori import apriori

# %%
data = pd.read_excel('Online Retail.xlsx')

# %% [markdown]
# ### Explore Data

# %%
data.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 5 2010-12-01 08:26:00       7.65     17850.0  United Kingdom
# 6 2010-12-01 08:26:00       4.25     17850.0  United Kingdom
# 7 2010-12-01 08:28:00       1.85     17850.0  United Kingdom
# 8 2010-12-01 08:28:00       1.85     17850.0  United Kingdom
# 9 2010-12-01 08:34:00       1.69     13047.0  United Kingdom

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
# InvoiceNo      541909 non-null object
# StockCode      541909 non-null object
# Description    540455 non-null object
# Quantity       541909 non-null int64
# InvoiceDate    541909 non-null datetime64[ns]
# UnitPrice      541909 non-null float64
# CustomerID     406829 non-null float64
# Country        541909 non-null object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
data.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
# Number of unqiue invoices
data.InvoiceNo.nunique()
# Out:
# 25900

# %%
# Number of unique Data Items - slight descrepancy between code and description but not too bad
print(data.StockCode.nunique())
print(data.Description.nunique())
# Out:
# 4070
# 4223

# %%
# Top 20 items have support of around 5-10%
data.groupby('Description').InvoiceNo.count().sort_values(ascending = False).head(20)
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER    2369
# REGENCY CAKESTAND 3 TIER              2200
# JUMBO BAG RED RETROSPOT               2159
# PARTY BUNTING                         1727
# LUNCH BAG RED RETROSPOT               1638
# ASSORTED COLOUR BIRD ORNAMENT         1501
# SET OF 3 CAKE TINS PANTRY DESIGN      1473
# PACK OF 72 RETROSPOT CAKE CASES       1385
# LUNCH BAG  BLACK SKULL.               1350
# NATURAL SLATE HEART CHALKBOARD        1280
# POSTAGE                               1252
# JUMBO BAG PINK POLKADOT               1251
# HEART OF WICKER SMALL                 1237
# JAM MAKING SET WITH JARS              1229
# JUMBO STORAGE BAG SUKI                1214
# PAPER CHAIN KIT 50'S CHRISTMAS        1210
# JUMBO SHOPPER VINTAGE RED PAISLEY     1202
# LUNCH BAG CARS BLUE                   1197
# LUNCH BAG SPACEBOY DESIGN             1192
# JAM MAKING SET PRINTED                1182
# Name: InvoiceNo, dtype: int64

# %% [markdown]
# ### Quick Data Prep and Market-Basket with Apriori

# %%
# Use only 400,000 clean lines
df = data.dropna().iloc[0:400000]

# %%
# number of unique invoices and items
print(df.InvoiceNo.nunique())
print(df.Description.nunique())
# Out:
# 21823
# 3894

# %%
# Support 5-10%
df.groupby('Description').InvoiceNo.count().sort_values(ascending = False).head(20)
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER    2052
# REGENCY CAKESTAND 3 TIER              1885
# JUMBO BAG RED RETROSPOT               1641
# PARTY BUNTING                         1411
# ASSORTED COLOUR BIRD ORNAMENT         1404
# LUNCH BAG RED RETROSPOT               1344
# SET OF 3 CAKE TINS PANTRY DESIGN      1220
# POSTAGE                               1176
# LUNCH BAG  BLACK SKULL.               1113
# PACK OF 72 RETROSPOT CAKE CASES       1074
# SPOTTY BUNTING                        1022
# LUNCH BAG SPACEBOY DESIGN             1014
# LUNCH BAG CARS BLUE                   1008
# PAPER CHAIN KIT 50'S CHRISTMAS         993
# NATURAL SLATE HEART CHALKBOARD         989
# HEART OF WICKER SMALL                  985
# LUNCH BAG PINK POLKADOT                971
# JAM MAKING SET WITH JARS               961
# REX CASH+CARRY JUMBO SHOPPER           943
# LUNCH BAG SUKI DESIGN                  943
# Name: InvoiceNo, dtype: int64

# %%
df = df[['InvoiceNo', 'Description']]

# %%
# Put transaction data into list of list form for use with Apriori algorithm
# SLOW: Should probably pre-allocate the list (for 100,000 items was only 30s)
import time

start = time.time()

invoices = list(df.InvoiceNo.unique())

records = []
for i in range(len(invoices)):
    records.append(list(df.Description[df.InvoiceNo == invoices[i]]))

end = time.time()

print(end-start)
# Out:
# 485.76213932037354

# %%
# Play with rules and fit algorithm
association_rules = apriori(records, min_support=0.015, min_confidence=0.3, min_lift=3, min_length=2)  
association_results = list(association_rules)

# %%
# How many pairs met the criteria?
print(len(association_results))
# Out:
# 49

# %%
# Print details for the 49 pairs

for item in association_results[0:49]:
    pair = item[0] 
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])

    print("Support: " + str(item[1]))
    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Rule: PACK OF 72 RETROSPOT CAKE CASES -> 60 TEATIME FAIRY CAKE CASES
# Support: 0.01516748384731705
# Confidence: 0.5038051750380518
# Lift: 10.622744284884448
# =====================================
# Rule: ALARM CLOCK BAKELIKE PINK -> ALARM CLOCK BAKELIKE GREEN
# Support: 0.015579892773679146
# Confidence: 0.42875157629255994
# Lift: 15.06706223741149
# =====================================
# Rule: ALARM CLOCK BAKELIKE GREEN -> ALARM CLOCK BAKELIKE RED
# Support: 0.024011364157081976
# Confidence: 0.6607818411097099
# Lift: 16.257319186625928
# =====================================
# Rule: ALARM CLOCK BAKELIKE PINK -> ALARM CLOCK BAKELIKE RED
# Support: 0.01828346240205288
# Confidence: 0.642512077294686
# Lift: 15.807825324466664
# =====================================
# Rule: DOLLY GIRL LUNCH BOX -> SPACEBOY LUNCH BOX
# Support: 0.019291573110938
# Confidence: 0.6790322580645162
# Lift: 21.01917867764814
# =====================================
# Rule: GARDENERS KNEELING PAD CUP OF TEA  -> GARDENERS KNEELING PAD KEEP CALM
# Support: 0.020803739174265683
# Confidence: 0.7275641025641025
# Lift: 21.31225692651867
# =====================================
# Rule: GREEN REGENCY TEACUP AND SAUCER -> PINK REGENCY TEACUP AND SAUCER
# Support: 0.021445264170828943
# Confidence: 0.6437414030261348
# Lift: 23.973325321227545
# =====================================
# Rule: GREEN REGENCY TEACUP AND SAUCER -> REGENCY CAKESTAND 3 TIER
# Support: 0.01745864454932869
# Confidence: 0.5240715268225584
# Lift: 6.132339372573026
# =====================================
# Rule: GREEN REGENCY TEACUP AND SAUCER -> ROSES REGENCY TEACUP AND SAUCER
# Support: 0.025294414150208496
# Confidence: 0.7592847317744155
# Lift: 20.01192113709308
# =====================================
# Rule: HEART OF WICKER LARGE -> HEART OF WICKER SMALL
# Support: 0.018558401686294277
# Confidence: 0.5006180469715698
# Lift: 11.344743135057701
# =====================================
# Rule: JUMBO BAG RED RETROSPOT -> JUMBO  BAG BAROQUE BLACK WHITE
# Support: 0.016817119552765433
# Confidence: 0.5628834355828222
# Lift: 7.568579922812033
# =====================================
# Rule: JUMBO BAG RED RETROSPOT -> JUMBO BAG APPLES
# Support: 0.016404710626403335
# Confidence: 0.4897400820793433
# Lift: 6.5850879921241585
# =====================================
# Rule: JUMBO BAG PINK POLKADOT -> JUMBO BAG RED RETROSPOT
# Support: 0.025294414150208496
# Confidence: 0.6279863481228669
# Lift: 8.443959380828913
# =====================================
# Rule: JUMBO BAG RED RETROSPOT -> JUMBO BAG PINK VINTAGE PAISLEY
# Support: 0.015304953489437749
# Confidence: 0.5520661157024793
# Lift: 7.423129293268766
# =====================================
# Rule: JUMBO BAG RED RETROSPOT -> JUMBO BAG STRAWBERRY
# Support: 0.019199926682857537
# Confidence: 0.631975867269985
# Lift: 8.497602804333262
# =====================================
# Rule: JUMBO BAG RED RETROSPOT -> JUMBO BAG VINTAGE LEAF
# Support: 0.01562571598771938
# Confidence: 0.4451697127937337
# Lift: 5.985790907145811
# =====================================
# Rule: JUMBO BAG RED RETROSPOT -> JUMBO SHOPPER VINTAGE RED PAISLEY
# Support: 0.018054346331851715
# Confidence: 0.4993662864385297
# Lift: 6.714522778156522
# =====================================
# Rule: JUMBO BAG RED RETROSPOT -> JUMBO STORAGE BAG SUKI
# Support: 0.020024744535581725
# Confidence: 0.5588235294117647
# Lift: 7.513990069225473
# =====================================
# Rule: JUMBO BAG RED RETROSPOT -> LUNCH BAG RED RETROSPOT
# Support: 0.019795628465380563
# Confidence: 0.3285171102661597
# Lift: 4.417269807355764
# =====================================
# Rule: LUNCH BAG CARS BLUE -> LUNCH BAG  BLACK SKULL.
# Support: 0.019337396324978235
# Confidence: 0.3977379830348728
# Lift: 8.812016247482262
# =====================================
# Rule: LUNCH BAG PINK POLKADOT -> LUNCH BAG  BLACK SKULL.
# Support: 0.021307794528708245
# Confidence: 0.43826578699340246
# Lift: 10.120925152970393
# =====================================
# Rule: LUNCH BAG RED RETROSPOT -> LUNCH BAG  BLACK SKULL.
# Support: 0.023644778444760116
# Confidence: 0.48633364750235625
# Lift: 8.070919535698799
# =====================================
# Rule: LUNCH BAG SPACEBOY DESIGN  -> LUNCH BAG  BLACK SKULL.
# Support: 0.01897081061265637
# Confidence: 0.3901979264844486
# Lift: 8.56668948658966
# =====================================
# Rule: LUNCH BAG SUKI DESIGN  -> LUNCH BAG  BLACK SKULL.
# Support: 0.018695871328414975
# Confidence: 0.3845428840716305
# Lift: 9.231990494054118
# =====================================
# Rule: LUNCH BAG WOODLAND -> LUNCH BAG  BLACK SKULL.
# Support: 0.01599230170004124
# Confidence: 0.3289349670122526
# Lift: 8.679985229877133
# =====================================
# Rule: LUNCH BAG RED RETROSPOT -> LUNCH BAG APPLE DESIGN
# Support: 0.017825230261650553
# Confidence: 0.4466130884041332
# Lift: 7.411739489158479
# =====================================
# Rule: LUNCH BAG APPLE DESIGN -> LUNCH BAG SUKI DESIGN
# Support: 0.016496357054483803
# Confidence: 0.4133180252583238
# Lift: 9.922815473280968
# =====================================
# Rule: LUNCH BAG PINK POLKADOT -> LUNCH BAG CARS BLUE
# Support: 0.01974980525134033
# Confidence: 0.43756345177664974
# Lift: 10.104706040340558
# =====================================
# Rule: LUNCH BAG RED RETROSPOT -> LUNCH BAG CARS BLUE
# Support: 0.021170324886587544
# Confidence: 0.4690355329949238
# Lift: 7.783849761633629
# =====================================
# Rule: LUNCH BAG SPACEBOY DESIGN  -> LUNCH BAG CARS BLUE
# Support: 0.018008523117811485
# Confidence: 0.39898477157360407
# Lift: 8.759602283753281
# =====================================
# Rule: LUNCH BAG SUKI DESIGN  -> LUNCH BAG CARS BLUE
# Support: 0.018008523117811485
# Confidence: 0.39898477157360407
# Lift: 9.578707007756615
# =====================================
# Rule: LUNCH BAG WOODLAND -> LUNCH BAG CARS BLUE
# Support: 0.0167712963387252
# Confidence: 0.3715736040609137
# Lift: 9.805139977534848
# =====================================
# Rule: LUNCH BAG DOLLY GIRL DESIGN -> LUNCH BAG SPACEBOY DESIGN
# Support: 0.016175594556202173
# Confidence: 0.5873544093178037
# Lift: 12.895206513624174
# =====================================
# Rule: LUNCH BAG RED RETROSPOT -> LUNCH BAG PINK POLKADOT
# Support: 0.024194657013242908
# Confidence: 0.5587301587301586
# Lift: 9.272371295793347
# =====================================
# Rule: LUNCH BAG SPACEBOY DESIGN  -> LUNCH BAG PINK POLKADOT
# Support: 0.016908765980845897
# Confidence: 0.3904761904761905
# Lift: 8.572798696943567
# =====================================
# Rule: LUNCH BAG SUKI DESIGN  -> LUNCH BAG PINK POLKADOT
# Support: 0.01645053384044357
# Confidence: 0.3798941798941799
# Lift: 9.120385795193277
# =====================================
# Rule: LUNCH BAG RED RETROSPOT -> LUNCH BAG SPACEBOY DESIGN
# Support: 0.02139944095678871
# Confidence: 0.35513307984790876
# Lift: 7.796850303340959
# =====================================
# Rule: LUNCH BAG RED RETROSPOT -> LUNCH BAG SUKI DESIGN
# Support: 0.020849562388305917
# Confidence: 0.34600760456273766
# Lift: 8.306847034513337
# =====================================
# Rule: LUNCH BAG RED RETROSPOT -> LUNCH BAG WOODLAND
# Support: 0.01993309810750126
# Confidence: 0.33079847908745247
# Lift: 8.729159865931651
# =====================================
# Rule: LUNCH BAG SPACEBOY DESIGN  -> LUNCH BAG SUKI DESIGN
# Support: 0.01745864454932869
# Confidence: 0.3832997987927565
# Lift: 9.202146874647223
# =====================================
# Rule: LUNCH BAG SPACEBOY DESIGN  -> LUNCH BAG WOODLAND
# Support: 0.018558401686294277
# Confidence: 0.4074446680080483
# Lift: 10.751710991462682
# =====================================
# Rule: PACK OF 60 PINK PAISLEY CAKE CASES -> PACK OF 72 RETROSPOT CAKE CASES
# Support: 0.015396599917518215
# Confidence: 0.5052631578947369
# Lift: 10.65348588863463
# =====================================
# Rule: PAPER CHAIN KIT 50'S CHRISTMAS  -> PAPER CHAIN KIT VINTAGE CHRISTMAS
# Support: 0.020162214177702423
# Confidence: 0.4602510460251046
# Lift: 14.620172601755252
# =====================================
# Rule: SPOTTY BUNTING -> PARTY BUNTING
# Support: 0.01796269990377125
# Confidence: 0.3888888888888889
# Lift: 6.088036027419097
# =====================================
# Rule: ROSES REGENCY TEACUP AND SAUCER  -> PINK REGENCY TEACUP AND SAUCER
# Support: 0.020482976675984053
# Confidence: 0.7627986348122867
# Lift: 20.104534550131078
# =====================================
# Rule: WHITE HANGING HEART T-LIGHT HOLDER -> RED HANGING HEART T-LIGHT HOLDER
# Support: 0.02075791596022545
# Confidence: 0.668141592920354
# Lift: 7.308698737995432
# =====================================
# Rule: REGENCY CAKESTAND 3 TIER -> ROSES REGENCY TEACUP AND SAUCER
# Support: 0.019658158823259865
# Confidence: 0.5181159420289856
# Lift: 6.062651047130592
# =====================================
# Rule: WOODEN FRAME ANTIQUE WHITE  -> WOODEN PICTURE FRAME WHITE FINISH
# Support: 0.021491087384869174
# Confidence: 0.5740514075887393
# Lift: 14.139417458023768
# =====================================
# Rule: GREEN REGENCY TEACUP AND SAUCER -> ROSES REGENCY TEACUP AND SAUCER
# Support: 0.018054346331851715
# Confidence: 0.8418803418803418
# Lift: 22.188834179776208
# =====================================
